# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
f = open("file.txt", "r")

# %%
data = f.readlines()

# %%
type(data)
# Out:
# list

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                                    0
# 0  {'ctm': 1256511600000, 'ctmString': 'Oct 26, 2...

# %%
ndf = df[0][0]

# %%
type(ndf)
# Out:
# str

# %%
import ast

# %%
list_of_dictionaries = ast.literal_eval(ndf)

# %%
type(list_of_dictionaries)
# Out:
# tuple

# %%
arebhai = list(list_of_dictionaries)

# %%
pdf = pd.DataFrame(arebhai)

# %%
pdf.head()
# Out:
#    close            ctm                 ctmString   high     low     open  vol
# 0 -220.0  1256511600000  Oct 26, 2009 12:00:00 AM  335.0 -1017.0  52374.0  0.0
# 1 -539.0  1257462000000   Nov 6, 2009 12:00:00 AM  999.0 -1492.0  51029.0  0.0
# 2  690.0  1257721200000   Nov 9, 2009 12:00:00 AM  693.0   -69.0  51714.0  0.0
# 3    1.0  1257894000000  Nov 11, 2009 12:00:00 AM  304.0  -203.0  52582.0  0.0
# 4 -508.0  1259017200000  Nov 24, 2009 12:00:00 AM  648.0 -1087.0  53091.0  0.0

# %%
pdf['Date'] = pd.to_datetime(pdf['ctmString'])

# %%
pdf.head()
# Out:
#    close            ctm                 ctmString   high     low     open  \
# 0 -220.0  1256511600000  Oct 26, 2009 12:00:00 AM  335.0 -1017.0  52374.0
# 1 -539.0  1257462000000   Nov 6, 2009 12:00:00 AM  999.0 -1492.0  51029.0
# 2  690.0  1257721200000   Nov 9, 2009 12:00:00 AM  693.0   -69.0  51714.0
# 3    1.0  1257894000000  Nov 11, 2009 12:00:00 AM  304.0  -203.0  52582.0
# 4 -508.0  1259017200000  Nov 24, 2009 12:00:00 AM  648.0 -1087.0  53091.0
#
#    vol       Date
# 0  0.0 2009-10-26
# 1  0.0 2009-11-06
# 2  0.0 2009-11-09
# 3  0.0 2009-11-11
# 4  0.0 2009-11-24

# %%
pdf.set_index('Date')
# Out:
#              close            ctm                 ctmString    high     low  \
# Date
# 2009-10-26  -220.0  1256511600000  Oct 26, 2009 12:00:00 AM   335.0 -1017.0
# 2009-11-06  -539.0  1257462000000   Nov 6, 2009 12:00:00 AM   999.0 -1492.0
# 2009-11-09   690.0  1257721200000   Nov 9, 2009 12:00:00 AM   693.0   -69.0
# 2009-11-11     1.0  1257894000000  Nov 11, 2009 12:00:00 AM   304.0  -203.0
# 2009-11-24  -508.0  1259017200000  Nov 24, 2009 12:00:00 AM   648.0 -1087.0
# 2009-11-25     8.0  1259103600000  Nov 25, 2009 12:00:00 AM    66.0  -381.0
# 2009-11-26 -1286.0  1259190000000  Nov 26, 2009 12:00:00 AM    35.0 -1445.0
# 2009-11-27  1137.0  1259276400000  Nov 27, 2009 12:00:00 AM  1502.0     0.0
# 2009-12-09    58.0  1260313200000   Dec 9, 2009 12:00:00 AM   423.0 -1079.0
# 2009-12-15  -164.0  1260831600000  Dec 15, 2009 12:00:00 AM     0.0 -1363.0
# 2009-12-22  -126.0  1261436400000  Dec 22, 2009 12:00:00 AM   720.0 -1245.0
# 2010-01-14 -1038.0  1263423600000  Jan 14, 2010 12:00:00 AM   908.0 -1620.0
# 2010-01-28  -222.0  1264633200000  Jan 28, 2010 12:00:00 AM  2804.0 -1347.0
# 2020-06-03  62478.0  482898.0
# 2020-06-04  63897.0  544094.0
# 2020-06-05  63356.0  561494.0
# 2020-06-08  64813.0  539417.0
# 2020-06-09  64903.0  583903.0
#
# [2311 rows x 7 columns]

# %%
usable_data = []
data = pd.DataFrame(usable_data)

# %%
data['Open'] = pdf['open']

# %%
data['High'] = pdf['high']
data['Low'] = pdf['low']
data['Close'] = pdf['close']
data['Date'] = pdf['Date']

# %%
data.head()
# Out:
#       Open   High     Low  Close       Date
# 0  52374.0  335.0 -1017.0 -220.0 2009-10-26
# 1  51029.0  999.0 -1492.0 -539.0 2009-11-06
# 2  51714.0  693.0   -69.0  690.0 2009-11-09
# 3  52582.0  304.0  -203.0    1.0 2009-11-11
# 4  53091.0  648.0 -1087.0 -508.0 2009-11-24

# %%
data.set_index('Date',inplace=True)

# %%
data.head()
# Out:
#                Open   High     Low  Close
# Date
# 2009-10-26  52374.0  335.0 -1017.0 -220.0
# 2009-11-06  51029.0  999.0 -1492.0 -539.0
# 2009-11-09  51714.0  693.0   -69.0  690.0
# 2009-11-11  52582.0  304.0  -203.0    1.0
# 2009-11-24  53091.0  648.0 -1087.0 -508.0

# %%
#data.to_excel('UK100 Data.xlsx')

# %%
data['High Price'] = data['Open'] + data['High']

# %%
data['Low Price'] = data['Open'] + data['Low']

# %%
data.head()
# Out:
#                Open   High     Low  Close  High Price  Low Price
# Date
# 2009-10-26  52374.0  335.0 -1017.0 -220.0     52709.0    51357.0
# 2009-11-06  51029.0  999.0 -1492.0 -539.0     52028.0    49537.0
# 2009-11-09  51714.0  693.0   -69.0  690.0     52407.0    51645.0
# 2009-11-11  52582.0  304.0  -203.0    1.0     52886.0    52379.0
# 2009-11-24  53091.0  648.0 -1087.0 -508.0     53739.0    52004.0

# %%
#data.to_excel('Daily Data.xlsx')

# %%
data['High'].plot(kind='box')

# %%
data['Low'].plot(kind='box')

# %%
data['High'].quantile([0.4,0.5,0.85])
# Out:
# 0.40    249.0
# 0.50    315.0
# 0.85    749.5
# Name: High, dtype: float64

# %%
data['Low'].quantile([0.15,0.5,0.6])
# Out:
# 0.15   -836.0
# 0.50   -323.0
# 0.60   -245.0
# Name: Low, dtype: float64

# %%
nontradingdays = data[(data['Low'] < -850) | (data['High'] > 850)]

# %%
msngdys = len(nontradingdays)/len(data)
print(msngdys)
# Out:
# 0.2418866291648637

# %%
untradable_day = data[(data['Low'] > -120.1) | (data['High'] < 120.1)]

# %%
untradable_day.head()
# Out:
#                Open    High     Low   Close  High Price  Low Price
# Date
# 2009-11-09  51714.0   693.0   -69.0   690.0     52407.0    51645.0
# 2009-11-25  53644.0    66.0  -381.0     8.0     53710.0    53263.0
# 2009-11-26  53264.0    35.0 -1445.0 -1286.0     53299.0    51819.0
# 2009-11-27  51200.0  1502.0     0.0  1137.0     52702.0    51200.0
# 2009-12-15  53283.0     0.0 -1363.0  -164.0     53283.0    51920.0

# %%
#untradable_day.to_excel('Untradable Days.xlsx')

# %%
pct_bad_days = len(untradable_day)/len(data)

# %%
print(pct_bad_days)
# Out:
# 0.42276070964950235

# %%
data['Low'].median()
# Out:
# -323.0

# %%
data['High'].median()
# Out:
# 315.0

# %%
data['High'].plot(figsize=(16,9))
data['Low'].plot(c='r')
plt.axhline(120,c='black')
plt.axhline(-120,c='black')

# %%
untradable_day['High'].plot(figsize=(16,9))
untradable_day['Low'].plot(c='r')
plt.axhline(120,c='black')
plt.axhline(-120,c='black')

# %%
np.corrcoef(untradable_day['High'],untradable_day['Low'])
# Out:
# array([[1.       , 0.5341957],
#        [0.5341957, 1.       ]])

# %%
daily_uk100 = [data['Open'],data['High'],data['Low'],data['Close']]

# %%
placeholder = pd.concat(daily_uk100,axis=1)

# %%
placeholder.head()
# Out:
#                Open   High     Low  Close
# Date
# 2009-10-26  52374.0  335.0 -1017.0 -220.0
# 2009-11-06  51029.0  999.0 -1492.0 -539.0
# 2009-11-09  51714.0  693.0   -69.0  690.0
# 2009-11-11  52582.0  304.0  -203.0    1.0
# 2009-11-24  53091.0  648.0 -1087.0 -508.0

# %%
placeholder['High Price'] = placeholder['Open'] + placeholder['High']

# %%
placeholder['Low Price'] = placeholder['Open'] + placeholder['Low']

# %%
placeholder['Spread'] = placeholder['High Price'] - placeholder['Low Price']

# %%
placeholder.head()
# Out:
#                Open   High     Low  Close  High Price  Low Price  Spread
# Date
# 2009-10-26  52374.0  335.0 -1017.0 -220.0     52709.0    51357.0  1352.0
# 2009-11-06  51029.0  999.0 -1492.0 -539.0     52028.0    49537.0  2491.0
# 2009-11-09  51714.0  693.0   -69.0  690.0     52407.0    51645.0   762.0
# 2009-11-11  52582.0  304.0  -203.0    1.0     52886.0    52379.0   507.0
# 2009-11-24  53091.0  648.0 -1087.0 -508.0     53739.0    52004.0  1735.0

# %%
placeholder.drop(columns=['High','Low'],inplace=True)

# %%
placeholder.head()
# Out:
#                Open  Close  High Price  Low Price  Spread
# Date
# 2009-10-26  52374.0 -220.0     52709.0    51357.0  1352.0
# 2009-11-06  51029.0 -539.0     52028.0    49537.0  2491.0
# 2009-11-09  51714.0  690.0     52407.0    51645.0   762.0
# 2009-11-11  52582.0    1.0     52886.0    52379.0   507.0
# 2009-11-24  53091.0 -508.0     53739.0    52004.0  1735.0

# %%
type(placeholder)
# Out:
# pandas.core.frame.DataFrame

# %%
placeholder['Spread'].quantile([0.01,0.1,0.25])
# Out:
# 0.01    255.2
# 0.10    402.0
# 0.25    529.5
# Name: Spread, dtype: float64

# %%
logic = ({'Open'  : 'first',
         'High Price'  : 'max',
         'Low Price'   : 'min',
         'Close' : 'last'})

offset = pd.offsets.timedelta(days=-6)

placeholder.resample('W', loffset=offset).apply(logic).head()
# Out:
#                Open  High Price  Low Price   Close
# Date
# 2009-10-26  52374.0     52709.0    51357.0  -220.0
# 2009-11-02  51029.0     52028.0    49537.0  -539.0
# 2009-11-09  51714.0     52886.0    51645.0     1.0
# 2009-11-16      NaN         NaN        NaN     NaN
# 2009-11-23  53091.0     53739.0    51200.0  1137.0

# %%
weekly_uk100 = placeholder.resample('W', loffset=offset).apply(logic).dropna()

# %%
weekly_uk100.head()
# Out:
#                Open  High Price  Low Price   Close
# Date
# 2009-10-26  52374.0     52709.0    51357.0  -220.0
# 2009-11-02  51029.0     52028.0    49537.0  -539.0
# 2009-11-09  51714.0     52886.0    51645.0     1.0
# 2009-11-23  53091.0     53739.0    51200.0  1137.0
# 2009-12-07  52279.0     52702.0    51200.0    58.0

# %%
weekly_uk100['High'] = weekly_uk100['High Price'] - weekly_uk100['Open']

# %%
weekly_uk100['High'].quantile([0.1,0.5])
# Out:
# 0.1    156.0
# 0.5    740.5
# Name: High, dtype: float64

# %%
weekly_uk100['Low'] = weekly_uk100['Open'] - weekly_uk100['Low Price']

# %%
weekly_uk100['Low'].quantile([0.1,0.5])
# Out:
# 0.1    143.0
# 0.5    751.0
# Name: Low, dtype: float64

# %%
import numpy as np

# %%
np.corrcoef(weekly_uk100['Low'],weekly_uk100['High'])
# Out:
# array([[ 1.        , -0.24538439],
#        [-0.24538439,  1.        ]])

# %%
#weekly_uk100['Open'].plot(figsize=(16,9))
weekly_uk100['High Price'].plot(figsize=(16,9))
weekly_uk100['Low Price'].plot()

# %%
weekly_uk100['High'].plot(figsize=(16,9),c='green',xlim=('2009-10-06','2020-06-09'),ylim=(0,11000))
weekly_uk100['Low'].plot(c='r')
plt.axhline(120,c='black')

# %%
anom_weeks = weekly_uk100[(weekly_uk100['Low'] < 120.1) | (weekly_uk100['High'] < 120.1)]

# %%
pct_untradable_weeks = len(anom_weeks)/len(weekly_uk100)
print(pct_untradable_weeks)
# Out:
# 0.15808823529411764

# %%
weekly_uk100.head()
# Out:
#                Open  High Price  Low Price   Close    High     Low
# Date
# 2009-10-26  52374.0     52709.0    51357.0  -220.0   335.0  1017.0
# 2009-11-02  51029.0     52028.0    49537.0  -539.0   999.0  1492.0
# 2009-11-09  51714.0     52886.0    51645.0     1.0  1172.0    69.0
# 2009-11-23  53091.0     53739.0    51200.0  1137.0   648.0  1891.0
# 2009-12-07  52279.0     52702.0    51200.0    58.0   423.0  1079.0

# %%
weekly_uk100.to_csv('Weekly Data.csv')

# %%
anom_weeks.tail()
# Out:
#                Open  High Price  Low Price   Close    High     Low
# Date
# 2020-01-13  75226.0     76266.0    75151.0   450.0  1040.0    75.0
# 2020-01-20  76247.0     76267.0    74366.0  -166.0    20.0  1881.0
# 2020-02-03  72161.0     74732.0    72122.0  -455.0  2571.0    39.0
# 2020-05-18  58441.0     61118.0    58417.0  -100.0  2677.0    24.0
# 2020-06-01  60747.0     64968.0    60672.0  1156.0  4221.0    75.0

# %%
anom_weeks['High'].plot(figsize=(16,9),c='g',xlim=('2009-11-09','2020-06-01'),ylim=(0,7000))
anom_weeks['Low'].plot(c='r')

# %%
weekly_uk100['High'].quantile([0.5,0.8,0.99])
# Out:
# 0.50     740.50
# 0.80    1390.60
# 0.99    3419.52
# Name: High, dtype: float64

# %%
weekly_uk100['Low'].quantile([0.5,0.8,0.99])
# Out:
# 0.50     751.00
# 0.80    1544.60
# 0.99    4611.68
# Name: Low, dtype: float64

# %%
anom_low = weekly_uk100[(weekly_uk100['Low'] < 120.1)]

# %%
anom_high = weekly_uk100[(weekly_uk100['High'] < 120.1)]

# %%
anom_low['High'].quantile([0.99])
# Out:
# 0.99    3834.66
# Name: High, dtype: float64

# %%
anom_high['Low'].quantile([0.99])
# Out:
# 0.99    6115.73
# Name: Low, dtype: float64

# %%
weekly_uk100['High Price'].plot(figsize=(16,9),xlim=('2014-01-01','2014-02-11'),ylim=(60000,69000))
weekly_uk100['Low Price'].plot()
